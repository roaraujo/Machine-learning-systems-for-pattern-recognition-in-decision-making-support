# %% [markdown]
# # Instâncias reais

# %% [markdown]
# * **timestamp**: observations timestamps loaded into pandas DataFrame as its index;
# * **P-PDG**: pressure variable at the Permanent Downhole Gauge (PDG);
# * **P-TPT**: pressure variable at the Temperature and Pressure Transducer (TPT);
# * **T-TPT**: temperature variable at the Temperature and Pressure Transducer (TPT);
# * **P-MON-CKP**: pressure variable upstream of the production choke (CKP);
# * **T-JUS-CKP**: temperature variable downstream of the production choke (CKP);
# * **P-JUS-CKGL**: pressure variable upstream of the gas lift choke (CKGL);
# * **T-JUS-CKGL**: temperature variable upstream of the gas lift choke (CKGL);
# * **QGL**: gas lift flow rate;
# * **class**: observations labels associated with three types of periods (normal, fault transient, and faulty steady state).
#
#
# * **label**: instance label (event type);
# * **well**: well name. Hand-drawn and simulated instances have fixed names. Real instances have names masked with incremental id;
# * **id**: instance identifier. Hand-drawn and simulated instances have incremental id. Each real instance has an id generated from its first timestamp.

# %% [markdown]
# ## Treinamento de modelos sem anomalias no conjunto de treino

# %% [markdown]
# https://github.com/petrobras/3W

# %%
import sys
import os
import pandas as pd
import numpy as np
import json
from time import time
import joblib
import pickle

from pyod.models.ecod import ECOD

from pyod.models.suod import SUOD

from pyod.models.xgbod import XGBOD

from pyod.models.loda import LODA

from pyod.models.pca import PCA

from pyod.models.iforest import IForest


from itertools import product


# import time
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

from sklearn.kernel_approximation import Nystroem
from sklearn.linear_model import SGDOneClassSVM
from sklearn.pipeline import make_pipeline
from sklearn.svm import OneClassSVM

from sklearn.model_selection import GroupKFold

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.metrics  import average_precision_score, make_scorer, roc_curve,f1_score, precision_score, recall_score, fbeta_score, auc, roc_auc_score, accuracy_score, confusion_matrix, classification_report,precision_recall_curve
import seaborn as sns

import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit

from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

# %% [markdown]
# ### Function to calculate metrics

# %%
def metrics(y_test, y_pred):
    cm = list()
    cm = confusion_matrix(y_test, y_pred)
    cm_df = pd.DataFrame(cm)                      
    plt.figure(figsize=(8,6))  
    sns.heatmap(cm_df, annot=True)
    print("Classification Report: \n", classification_report(y_test, y_pred, digits=5))  


    TN = cm[0][0]
    FP = cm[0][1]
    FN = cm[1][0]
    TP = cm[1][1]

    print("Specificity:", TN/(TN+FP))


    roc_auc_s = roc_auc_score(y_test, y_pred)
    gini = 2*roc_auc_s -1
    print("Gini: ",gini)
    print("ROC AUC:: ",roc_auc_s)

# %% [markdown]
# ## Read data

# %%
train = pd.read_parquet('./dataset/train_temp.parquet.gzip') 
test = pd.read_parquet('./dataset/test_temp.parquet.gzip')

# %%
VARS = ['P-PDG', 'P-TPT', 'T-TPT', 'P-MON-CKP', 'T-JUS-CKP', 'P-JUS-CKGL', 'QGL']

# %%
development = train.reset_index(drop=True)
development.shape
# Out:
# (8887177, 10)

# %%
train_no_anomalies = train[train.target==0]
train_no_anomalies.shape
# Out:
# (5872276, 10)

# %%
class ToDataFrameTransformer(BaseEstimator, TransformerMixin):
    """
    Transformador para converter arrays NumPy em DataFrames, mantendo os nomes das colunas.
    """
    def __init__(self, columns=None):
        self.columns = columns
    
    def fit(self, X, y=None):
        # Não há nada para ajustar, apenas retorna o próprio objeto
        return self

    def transform(self, X):
        # Converte o array NumPy em DataFrame com os nomes das colunas fornecidos
        if self.columns is not None:
            return pd.DataFrame(X, columns=self.columns)
        return pd.DataFrame(X)

    def fit_transform(self, X, y=None):
        return self.fit(X, y).transform(X)
    

def convert_param_grid(param_grid):
    param_grid_formatted = []
    
    # Gerar todas as combinações possíveis dos parâmetros usando itertools.product
    for combination in product(*param_grid.values()):
        params_dict = {key: value for key, value in zip(param_grid.keys(), combination)}
        param_grid_formatted.append({'params': params_dict})
    
    return param_grid_formatted


def cross_validation(estimator_class, param_grid, dataset, tscv, features, scikit = False, random_state=None):

    results = list()

    param_list = convert_param_grid(param_grid)

    # Iterar sobre todas as combinações de hiperparâmetros
    for params in param_list:
                    
        split_scores = {
            'f1_score': [],
            'specificity': [],
            'precision': [],
            'recall': [],
            'roc_auc':[],
            # 'pr_auc':[],
            'fit_time': [],
            'score_time': []
        }

        if estimator_class==SGDOneClassSVM:

            transform = Nystroem(gamma=None, random_state=42)
            estimator = estimator_class(random_state=random_state, **params['params'])
            estimator = make_pipeline(transform, estimator)


        else:
            if random_state==None:
                estimator = estimator_class(**params['params'])
            else:
                estimator = estimator_class(random_state=random_state, **params['params'])

        pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('to_dataframe', ToDataFrameTransformer(columns=features)),
            ('estimator', estimator)
        ])

        # TimeSeriesSplit
        for fold_idx, (train_index, test_index) in enumerate(tscv.split(dataset)):
            X_train_split = dataset[dataset.index.isin(train_index)]
            X_train_split = X_train_split[X_train_split.target==0]

            X_test_split = dataset[dataset.index.isin(test_index)]

            if X_test_split.target.mean()>0:
                print("taxa de anomalias:",  X_test_split.target.mean())
                start_fit = time()
                pipeline.fit(X_train_split[features])
                fit_time = time() - start_fit

                
                start_score = time()
                y_pred_split = pipeline.predict(X_test_split[features])
                score_time = time() - start_score

                # y_scores = pipeline.decision_function(X_test_split[features])


                if scikit==True:
                    y_pred_split = np.where(y_pred_split == -1, 1, 0)  
                
                y_true_split = X_test_split.target.values
                
                precision = precision_score(y_true_split, y_pred_split, zero_division=0)
                recall = recall_score(y_true_split, y_pred_split, zero_division=0)
                f1 = f1_score(y_true_split, y_pred_split, zero_division=0)
                try:
                    roc_auc = roc_auc_score(y_true_split, y_pred_split)

                except:
                    roc_auc = 0
                # pr_auc = average_precision_score(y_true_split, y_scores)
                
                if len(np.unique(y_true_split)) == 2 and len(np.unique(y_pred_split)) == 2:
                    tn, fp, fn, tp = confusion_matrix(y_true_split, y_pred_split).ravel()
                else:
                    tn, fp, fn, tp = (0, 0, 0, 0)

                specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
                
                split_scores['f1_score'].append(f1)
                split_scores['specificity'].append(specificity)
                split_scores['precision'].append(precision)
                split_scores['recall'].append(recall)
                split_scores['roc_auc'].append(roc_auc)
                # split_scores['pr_auc'].append(pr_auc)
                split_scores['fit_time'].append(fit_time)
                split_scores['score_time'].append(score_time)
            else:
                continue    

        results.append({
            'params': params['params'],
            'fold_scores': {
                'test_f1_scores': split_scores['f1_score'],
                'test_specificities': split_scores['specificity'],
                'test_precisions': split_scores['precision'],
                'test_recalls': split_scores['recall'],
                'test_roc_auc': split_scores['roc_auc'],
                # 'test_pr_auc': split_scores['pr_auc'],
                'fit_times': split_scores['fit_time'],
                'score_times': split_scores['score_time']
            },
            'mean_test_f1_score': np.mean(split_scores['f1_score']),
            'std_test_f1_score': np.std(split_scores['f1_score']),
            'mean_test_specificity': np.mean(split_scores['specificity']),
            'std_test_specificity': np.std(split_scores['specificity']),
            'mean_test_precision': np.mean(split_scores['precision']),
            'std_test_precision': np.std(split_scores['precision']),
            'mean_test_recall': np.mean(split_scores['recall']),
            'std_test_recall': np.std(split_scores['recall']),
            'mean_test_roc_auc': np.mean(split_scores['roc_auc']),
            'std_test_roc_auc': np.std(split_scores['roc_auc']),
            # 'mean_test_pr_auc': np.mean(split_scores['pr_auc']),
            # 'std_test_pr_auc': np.std(split_scores['pr_auc']),
            'mean_fit_time': np.mean(split_scores['fit_time']),
            'std_fit_time': np.std(split_scores['fit_time']),
            'mean_score_time': np.mean(split_scores['score_time']),
            'std_score_time': np.std(split_scores['score_time']),
        })
    results_df = pd.DataFrame(results)

    return results_df

# %%
def create_pipeline_with_kernel(estimator_class, params, kernel=None, gamma=None, random_state=None):
    if kernel:
        transform = Nystroem(kernel=kernel, gamma=gamma, random_state=random_state)
        estimator = estimator_class(random_state=random_state, **params)
        estimator = make_pipeline(transform, estimator)
    else:
        estimator = estimator_class(random_state=random_state, **params)
    
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('to_dataframe', ToDataFrameTransformer(columns=VARS)),
        ('estimator', estimator)
    ])
    return pipeline


def cross_validation_ocsvm(estimator_class, param_grid, dataset, tscv, features, scikit=False, random_state=None, kernels=None):

    results = list()

    param_list = convert_param_grid(param_grid)

    # Iterar sobre todas as combinações de hiperparâmetros
    for params in param_list:
                    
        split_scores = {
            'f1_score': [],
            'specificity': [],
            'precision': [],
            'recall': [],
            'roc_auc':[],
            # 'pr_auc':[],
            'fit_time': [],
            'score_time': []
        }

        # Loop sobre kernels, se definidos
        for kernel in kernels or [None]:  # Se não houver kernel, apenas None
            print(f"Treinando com kernel: {kernel} e parâmetros: {params['params']}")
            
            pipeline = create_pipeline_with_kernel(
                estimator_class=SGDOneClassSVM if kernel else estimator_class,
                params=params['params'],
                kernel=kernel,
                random_state=random_state
            )

                    # TimeSeriesSplit
            for fold_idx, (train_index, test_index) in enumerate(tscv.split(dataset)):
                X_train_split = dataset[dataset.index.isin(train_index)]
                X_train_split = X_train_split[X_train_split.target==0]

                X_test_split = dataset[dataset.index.isin(test_index)]

                if X_test_split.target.mean()>0:
                    print("taxa de anomalias:",  X_test_split.target.mean())
                    start_fit = time()
                    pipeline.fit(X_train_split[features])
                    fit_time = time() - start_fit

                    
                    start_score = time()
                    y_pred_split = pipeline.predict(X_test_split[features])
                    score_time = time() - start_score

                    # y_scores = pipeline.decision_function(X_test_split[features])


                    if scikit==True:
                        y_pred_split = np.where(y_pred_split == -1, 1, 0)  
                    
                    y_true_split = X_test_split.target.values
                    
                    precision = precision_score(y_true_split, y_pred_split, zero_division=0)
                    recall = recall_score(y_true_split, y_pred_split, zero_division=0)
                    f1 = f1_score(y_true_split, y_pred_split, zero_division=0)
                    try:
                        roc_auc = roc_auc_score(y_true_split, y_pred_split)

                    except:
                        roc_auc = 0
                    # pr_auc = average_precision_score(y_true_split, y_scores)
                    
                    if len(np.unique(y_true_split)) == 2 and len(np.unique(y_pred_split)) == 2:
                        tn, fp, fn, tp = confusion_matrix(y_true_split, y_pred_split).ravel()
                    else:
                        tn, fp, fn, tp = (0, 0, 0, 0)

                    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
                    
                    split_scores['f1_score'].append(f1)
                    split_scores['specificity'].append(specificity)
                    split_scores['precision'].append(precision)
                    split_scores['recall'].append(recall)
                    split_scores['roc_auc'].append(roc_auc)
                    # split_scores['pr_auc'].append(pr_auc)
                    split_scores['fit_time'].append(fit_time)
                    split_scores['score_time'].append(score_time)
                else:
                    continue    

            results.append({
                'kernel':kernel,
                'params': params['params'],
                'fold_scores': {
                    'test_f1_scores': split_scores['f1_score'],
                    'test_specificities': split_scores['specificity'],
                    'test_precisions': split_scores['precision'],
                    'test_recalls': split_scores['recall'],
                    'test_roc_auc': split_scores['roc_auc'],
                    # 'test_pr_auc': split_scores['pr_auc'],
                    'fit_times': split_scores['fit_time'],
                    'score_times': split_scores['score_time']
                },
                'mean_test_f1_score': np.mean(split_scores['f1_score']),
                'std_test_f1_score': np.std(split_scores['f1_score']),
                'mean_test_specificity': np.mean(split_scores['specificity']),
                'std_test_specificity': np.std(split_scores['specificity']),
                'mean_test_precision': np.mean(split_scores['precision']),
                'std_test_precision': np.std(split_scores['precision']),
                'mean_test_recall': np.mean(split_scores['recall']),
                'std_test_recall': np.std(split_scores['recall']),
                'mean_test_roc_auc': np.mean(split_scores['roc_auc']),
                'std_test_roc_auc': np.std(split_scores['roc_auc']),
                # 'mean_test_pr_auc': np.mean(split_scores['pr_auc']),
                # 'std_test_pr_auc': np.std(split_scores['pr_auc']),
                'mean_fit_time': np.mean(split_scores['fit_time']),
                'std_fit_time': np.std(split_scores['fit_time']),
                'mean_score_time': np.mean(split_scores['score_time']),
                'std_score_time': np.std(split_scores['score_time']),
            })
    results_df = pd.DataFrame(results)

    return results_df

# %%
def cross_validation_ratios(estimator_class, param_grid, dataset, fold_ratios, features, scikit = False, random_state=None):

    results = list()

    param_list = convert_param_grid(param_grid)

    # Iterar sobre todas as combinações de hiperparâmetros
    for params in param_list:
                    
        split_scores = {
            'f1_score': [],
            'specificity': [],
            'precision': [],
            'recall': [],
            'roc_auc':[],
            # 'pr_auc':[],
            'fit_time': [],
            'score_time': []
        }

        if estimator_class==SGDOneClassSVM:

            transform = Nystroem(gamma=None, random_state=42)
            estimator = estimator_class(random_state=random_state, **params['params'])
            estimator = make_pipeline(transform, estimator)


        else:
            if random_state==None:
                estimator = estimator_class(**params['params'])
            else:
                estimator = estimator_class(random_state=random_state, **params['params'])

        pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('to_dataframe', ToDataFrameTransformer(columns=features)),
            ('estimator', estimator)
        ])

        # TimeSeriesSplit
        for ratios in fold_ratios:

            X_train_split = list()
            X_test_split = list()

            dataset = dataset.sort_values(by=['well', 'timestamp'])

            # Iterar sobre cada poco
            for poco_id, poco_data in dataset.groupby('well'):
                # Calcular o índice para dividir os dados em treinamento e teste
                split_index = int(ratios * len(poco_data))
                
                # Dividir os dados do poco em treinamento e teste
                poco_train = poco_data.iloc[:split_index]
                poco_test = poco_data.iloc[split_index:]
                
                # Adicionar os dados de treinamento e teste à lista
                X_train_split.append(poco_train)
                X_test_split.append(poco_test)

            # Concatenar os dados de treinamento e teste
            X_train_split = pd.concat(X_train_split)
            X_test_split = pd.concat(X_test_split)

            X_train_split = X_train_split[X_train_split.target==0]


            if X_test_split.target.mean()>0:
                print("taxa de anomalias:",  X_test_split.target.mean())
                start_fit = time()
                pipeline.fit(X_train_split[features])
                fit_time = time() - start_fit

                
                start_score = time()
                y_pred_split = pipeline.predict(X_test_split[features])
                score_time = time() - start_score

                # y_scores = pipeline.decision_function(X_test_split[features])


                if scikit==True:
                    y_pred_split = np.where(y_pred_split == -1, 1, 0)  
                
                y_true_split = X_test_split.target.values
                
                precision = precision_score(y_true_split, y_pred_split, zero_division=0)
                recall = recall_score(y_true_split, y_pred_split, zero_division=0)
                f1 = f1_score(y_true_split, y_pred_split, zero_division=0)
                try:
                    roc_auc = roc_auc_score(y_true_split, y_pred_split)
                except:
                    roc_auc = 0
                # pr_auc = average_precision_score(y_true_split, y_scores)
                
                if len(np.unique(y_true_split)) == 2 and len(np.unique(y_pred_split)) == 2:
                    tn, fp, fn, tp = confusion_matrix(y_true_split, y_pred_split).ravel()
                else:
                    tn, fp, fn, tp = (0, 0, 0, 0)

                specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
                
                split_scores['f1_score'].append(f1)
                split_scores['specificity'].append(specificity)
                split_scores['precision'].append(precision)
                split_scores['recall'].append(recall)
                split_scores['roc_auc'].append(roc_auc)
                # split_scores['pr_auc'].append(pr_auc)
                split_scores['fit_time'].append(fit_time)
                split_scores['score_time'].append(score_time)
            else:
                continue    

        results.append({
            'params': params['params'],
            'fold_scores': {
                'test_f1_scores': split_scores['f1_score'],
                'test_specificities': split_scores['specificity'],
                'test_precisions': split_scores['precision'],
                'test_recalls': split_scores['recall'],
                'test_roc_auc': split_scores['roc_auc'],
                # 'test_pr_auc': split_scores['pr_auc'],
                'fit_times': split_scores['fit_time'],
                'score_times': split_scores['score_time']
            },
            'mean_test_f1_score': np.mean(split_scores['f1_score']),
            'std_test_f1_score': np.std(split_scores['f1_score']),
            'mean_test_specificity': np.mean(split_scores['specificity']),
            'std_test_specificity': np.std(split_scores['specificity']),
            'mean_test_precision': np.mean(split_scores['precision']),
            'std_test_precision': np.std(split_scores['precision']),
            'mean_test_recall': np.mean(split_scores['recall']),
            'std_test_recall': np.std(split_scores['recall']),
            'mean_test_roc_auc': np.mean(split_scores['roc_auc']),
            'std_test_roc_auc': np.std(split_scores['roc_auc']),
            # 'mean_test_pr_auc': np.mean(split_scores['pr_auc']),
            # 'std_test_pr_auc': np.std(split_scores['pr_auc']),
            'mean_fit_time': np.mean(split_scores['fit_time']),
            'std_fit_time': np.std(split_scores['fit_time']),
            'mean_score_time': np.mean(split_scores['score_time']),
            'std_score_time': np.std(split_scores['score_time']),
        })
    results_df = pd.DataFrame(results)

    return results_df

# %% [markdown]
# ### Isolation Forest

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html

# %%
# Definir a grade de hiperparâmetros para o IsolationForest
param_grid = {
    'n_estimators': [50, 100, 256],      # Número de árvores na floresta
    'max_samples': ['auto', 0.7, 1.0],     # Fração de amostras para treinamento de cada árvore
    'contamination': [0.05, 0.01, 0.001], # Fração de dados que são esperados ser outliers
    'max_features': [1.0, 0.7],             # Número de recursos (features) a serem considerados para dividir em cada nó
    'n_jobs': [-1]
}

estimator_class = IsolationForest

# Configurar TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=3)

# %%
results_df_iforest = cross_validation(estimator_class, param_grid, development, tscv, VARS, scikit = True, random_state=42)
# Out:
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415

# %%
results_df_iforest
# Out:
#                                                params  \
# 0   {'n_estimators': 50, 'max_samples': 'auto', 'c...
# 1   {'n_estimators': 50, 'max_samples': 'auto', 'c...
# 2   {'n_estimators': 50, 'max_samples': 'auto', 'c...
# 3   {'n_estimators': 50, 'max_samples': 'auto', 'c...
# 4   {'n_estimators': 50, 'max_samples': 'auto', 'c...
# 5   {'n_estimators': 50, 'max_samples': 'auto', 'c...
# 6   {'n_estimators': 50, 'max_samples': 0.7, 'cont...
# 7   {'n_estimators': 50, 'max_samples': 0.7, 'cont...
# 8   {'n_estimators': 50, 'max_samples': 0.7, 'cont...
# 9   {'n_estimators': 50, 'max_samples': 0.7, 'cont...
# 10  {'n_estimators': 50, 'max_samples': 0.7, 'cont...
# 11  {'n_estimators': 50, 'max_samples': 0.7, 'cont...
# 12  {'n_estimators': 50, 'max_samples': 1.0, 'cont...
# 13  {'n_estimators': 50, 'max_samples': 1.0, 'cont...
# 14  {'n_estimators': 50, 'max_samples': 1.0, 'cont...
# 15  {'n_estimators': 50, 'max_samples': 1.0, 'cont...
# 16  {'n_estimators': 50, 'max_samples': 1.0, 'cont...
# 17  {'n_estimators': 50, 'max_samples': 1.0, 'cont...
# 18  {'n_estimators': 100, 'max_samples': 'auto', '...
# 19  {'n_estimators': 100, 'max_samples': 'auto', '...
# 20  {'n_estimators': 100, 'max_samples': 'auto', '...
# 21  {'n_estimators': 100, 'max_samples': 'auto', '...
# 22  {'n_estimators': 100, 'max_samples': 'auto', '...
# 23  {'n_estimators': 100, 'max_samples': 'auto', '...
# 24  {'n_estimators': 100, 'max_samples': 0.7, 'con...
# 25  {'n_estimators': 100, 'max_samples': 0.7, 'con...
# 26  {'n_estimators': 100, 'max_samples': 0.7, 'con...
# 27  {'n_estimators': 100, 'max_samples': 0.7, 'con...
# 28  {'n_estimators': 100, 'max_samples': 0.7, 'con...
# 29  {'n_estimators': 100, 'max_samples': 0.7, 'con...
# 30  {'n_estimators': 100, 'max_samples': 1.0, 'con...
# 31  {'n_estimators': 100, 'max_samples': 1.0, 'con...
# 32  {'n_estimators': 100, 'max_samples': 1.0, 'con...
# 33  {'n_estimators': 100, 'max_samples': 1.0, 'con...
# 34  {'n_estimators': 100, 'max_samples': 1.0, 'con...
# 35  {'n_estimators': 100, 'max_samples': 1.0, 'con...
# 36  {'n_estimators': 256, 'max_samples': 'auto', '...
# 37  {'n_estimators': 256, 'max_samples': 'auto', '...
# 38  {'n_estimators': 256, 'max_samples': 'auto', '...
# 39  {'n_estimators': 256, 'max_samples': 'auto', '...
# 40  {'n_estimators': 256, 'max_samples': 'auto', '...
# 41  {'n_estimators': 256, 'max_samples': 'auto', '...
# 42  {'n_estimators': 256, 'max_samples': 0.7, 'con...
# 43  {'n_estimators': 256, 'max_samples': 0.7, 'con...
# 44  {'n_estimators': 256, 'max_samples': 0.7, 'con...
# 45  {'n_estimators': 256, 'max_samples': 0.7, 'con...
# 46  {'n_estimators': 256, 'max_samples': 0.7, 'con...
# 47  {'n_estimators': 256, 'max_samples': 0.7, 'con...
# 48  {'n_estimators': 256, 'max_samples': 1.0, 'con...
# 49  {'n_estimators': 256, 'max_samples': 1.0, 'con...
# 50  {'n_estimators': 256, 'max_samples': 1.0, 'con...
# 51  {'n_estimators': 256, 'max_samples': 1.0, 'con...
# 52  {'n_estimators': 256, 'max_samples': 1.0, 'con...
# 53  {'n_estimators': 256, 'max_samples': 1.0, 'con...
#
#                                           fold_scores  mean_test_f1_score  \
# 0   {'test_f1_scores': [0.8808118206138321, 0.2221...            0.639982
# 1   {'test_f1_scores': [0.7845335879602001, 0.2224...            0.609729
# 2   {'test_f1_scores': [0.4154704215049831, 0.0, 0...            0.161288
# 3   {'test_f1_scores': [0.699327916397875, 0.0, 0....            0.558174
# 4   {'test_f1_scores': [0.0, 0.0, 0.0], 'test_spec...            0.000000
# 5   {'test_f1_scores': [0.06382622158025361, 0.0, ...            0.344538
# 6   {'test_f1_scores': [0.2814917601414536, 0.2003...            0.436229
# 7   {'test_f1_scores': [0.2814917601414536, 0.1991...            0.435410
# 8   {'test_f1_scores': [0.2814917601414536, 0.2167...            0.443921
# 9   {'test_f1_scores': [0.2814917601414536, 0.2143...            0.443636
# 10  {'test_f1_scores': [0.2814525470236864, 0.2223...            0.449735
# 11  {'test_f1_scores': [0.2814917601414536, 0.2219...            0.452600
# 12  {'test_f1_scores': [0.2814917601414536, 0.2002...            0.436400
# 13  {'test_f1_scores': [0.2814917601414536, 0.1988...            0.436245
# 14  {'test_f1_scores': [0.2814917601414536, 0.2156...            0.444224
# 15  {'test_f1_scores': [0.2814917601414536, 0.2136...            0.444294
# 16  {'test_f1_scores': [0.2814625166300548, 0.2221...            0.451349
# 17  {'test_f1_scores': [0.2814917601414536, 0.2216...            0.454096
# 18  {'test_f1_scores': [0.9288930688972652, 0.2224...            0.654977
# 19  {'test_f1_scores': [0.7502595561707998, 0.2224...            0.598042
# 20  {'test_f1_scores': [0.7796715880398225, 0.0, 0...            0.259891
# 21  {'test_f1_scores': [0.7120212061905655, 0.0, 0...            0.562316
# 22  {'test_f1_scores': [0.048313531167295455, 0.0,...            0.016105
# 23  {'test_f1_scores': [0.09415331924620787, 0.0, ...            0.230220
# 24  {'test_f1_scores': [0.2814917601414536, 0.2006...            0.436285
# 25  {'test_f1_scores': [0.2814917601414536, 0.2008...            0.436163
# 26  {'test_f1_scores': [0.2814917601414536, 0.2166...            0.443930
# 27  {'test_f1_scores': [0.2814917601414536, 0.2159...            0.443853
# 28  {'test_f1_scores': [0.2814917601414536, 0.2223...            0.450156
# 29  {'test_f1_scores': [0.2814917601414536, 0.2221...            0.451013
# 30  {'test_f1_scores': [0.2814917601414536, 0.2007...            0.436640
# 31  {'test_f1_scores': [0.2814917601414536, 0.2019...            0.437058
# 32  {'test_f1_scores': [0.2814917601414536, 0.2162...            0.444300
# 33  {'test_f1_scores': [0.2814917601414536, 0.2156...            0.444363
# 34  {'test_f1_scores': [0.2814744800050122, 0.2222...            0.450741
# 35  {'test_f1_scores': [0.2814917601414536, 0.2221...            0.452300
# 36  {'test_f1_scores': [0.9300543558101954, 0.2224...            0.654973
# 37  {'test_f1_scores': [0.8683524945696672, 0.2224...            0.635046
# 38  {'test_f1_scores': [0.9186980878964484, 0.0, 0...            0.306233
# 39  {'test_f1_scores': [0.8898413143878615, 0.0, 0...            0.615870
# 40  {'test_f1_scores': [0.8749605851330213, 0.0, 0...            0.291654
# 41  {'test_f1_scores': [0.47178772239975475, 0.0, ...            0.207013
# 42  {'test_f1_scores': [0.2814917601414536, 0.2010...            0.436483
# 43  {'test_f1_scores': [0.2814917601414536, 0.2029...            0.437189
# 44  {'test_f1_scores': [0.2814917601414536, 0.2167...            0.444220
# 45  {'test_f1_scores': [0.2814917601414536, 0.2178...            0.444748
# 46  {'test_f1_scores': [0.2814917601414536, 0.2223...            0.450582
# 47  {'test_f1_scores': [0.2814917601414536, 0.2222...            0.451868
# 48  {'test_f1_scores': [0.2814917601414536, 0.2006...            0.436247
# 49  {'test_f1_scores': [0.2814917601414536, 0.2029...            0.437243
# 50  {'test_f1_scores': [0.2814917601414536, 0.2159...            0.443747
# 51  {'test_f1_scores': [0.2814917601414536, 0.2173...            0.444590
# 52  {'test_f1_scores': [0.2814917601414536, 0.2223...            0.449286
# 53  {'test_f1_scores': [0.2814917601414536, 0.2222...            0.451913
#
#     std_test_f1_score  mean_test_specificity  std_test_specificity  \
# 0            0.296575               0.461048              0.403331
# 1            0.274301               0.431985              0.365777
# 2            0.181890               0.666667              0.471405
# 3            0.410443               0.666667              0.471405
# 4            0.000000               0.000000              0.000000
# 5            0.442886               0.666667              0.471405
# 6            0.278185               0.116044              0.142513
# 7            0.277904               0.111451              0.141972
# 8            0.276754               0.152525              0.164805
# 9            0.278163               0.153035              0.159122
# 10           0.280830               0.185170              0.165256
# 11           0.285098               0.203776              0.163401
# 12           0.278512               0.117291              0.141451
# 13           0.279340               0.117384              0.137472
# 14           0.277974               0.155600              0.161086
# 15           0.279604               0.158050              0.155701
# 16           0.283204               0.195675              0.163736
# 17           0.287447               0.213509              0.164059
# 18           0.309465               0.466985              0.410628
# 19           0.267191               0.437880              0.373250
# 20           0.367541               0.333333              0.471405
# 21           0.411849               0.666667              0.471405
# 22           0.022775               0.333333              0.471405
# 23           0.261841               0.666667              0.471405
# 24           0.278054               0.116187              0.143222
# 25           0.277710               0.115169              0.144494
# 26           0.276810               0.152647              0.164619
# 27           0.277278               0.152909              0.162760
# 28           0.281384               0.187787              0.164837
# 29           0.282720               0.193473              0.163873
# 30           0.278433               0.118451              0.142343
# 31           0.278165               0.120313              0.144450
# 32           0.277668               0.155555              0.162325
# 33           0.278165               0.156517              0.160728
# 34           0.282274               0.191667              0.164207
# 35           0.284588               0.201759              0.163495
# 36           0.309607               0.467139              0.410826
# 37           0.292602               0.457462              0.398315
# 38           0.433078               0.333333              0.471405
# 39           0.436368               0.666667              0.471405
# 40           0.412460               0.333333              0.471405
# 41           0.196889               0.666667              0.471405
# 42           0.278049               0.117209              0.143683
# 43           0.277557               0.120289              0.147388
# 44           0.277163               0.154499              0.163946
# 45           0.277121               0.156943              0.165208
# 46           0.281982               0.190533              0.164460
# 47           0.283848               0.198838              0.163750
# 48           0.277977               0.115904              0.143479
# 49           0.277666               0.120694              0.147032
# 50           0.277070               0.152122              0.163290
# 51           0.277236               0.156353              0.164468
# 52           0.280187               0.182198              0.165828
# 53           0.283911               0.199122              0.163744
#
#     mean_test_precision  std_test_precision  mean_test_recall  \
# 0              0.575349            0.329739          0.948930
# 1              0.490502            0.259162          0.997790
# 2              0.666667            0.471405          0.099204
# 3              0.666667            0.471405          0.496419
# 4              0.000000            0.000000          0.000000
# 5              0.666667            0.471405          0.324772
# 6              0.326644            0.268255          1.000000
# 7              0.325776            0.267560          1.000000
# 8              0.333303            0.270141          1.000000
# 9              0.333568            0.271636          1.000000
# 10             0.340359            0.277545          0.999946
# 11             0.344781            0.283933          1.000000
# 12             0.326924            0.268703          1.000000
# 13             0.327088            0.269568          1.000000
# 14             0.334050            0.271686          1.000000
# 15             0.334737            0.273602          1.000000
# 16             0.342830            0.281096          0.999960
# 17             0.347168            0.287454          1.000000
# 18             0.605365            0.361305          0.950711
# 19             0.494190            0.261432          0.956029
# 20             0.333333            0.471405          0.212968
# 21             0.666667            0.471405          0.501300
# 22             0.333333            0.471405          0.008252
# 23             0.666667            0.471405          0.158140
# 24             0.326647            0.268133          1.000000
# 25             0.326406            0.267688          1.000000
# 26             0.333333            0.270210          1.000000
# 27             0.333438            0.270715          1.000000
# 28             0.340974            0.278389          1.000000
# 29             0.342317            0.280365          1.000000
# 30             0.327118            0.268725          1.000000
# 31             0.327409            0.268615          1.000000
# 32             0.334005            0.271367          1.000000
# 33             0.334253            0.271971          1.000000
# 34             0.341882            0.279712          0.999976
# 35             0.344289            0.283184          1.000000
# 36             0.606085            0.362230          0.949914
# 37             0.558460            0.313373          0.955129
# 38             0.333333            0.471405          0.283207
# 39             0.666667            0.471405          0.573501
# 40             0.333333            0.471405          0.259238
# 41             0.666667            0.471405          0.129788
# 42             0.326830            0.268218          1.000000
# 43             0.327305            0.267988          1.000000
# 44             0.333738            0.270749          1.000000
# 45             0.334219            0.270939          1.000000
# 46             0.341615            0.279293          1.000000
# 47             0.343581            0.282102          1.000000
# 48             0.326583            0.268029          1.000000
# 49             0.327396            0.268135          1.000000
# 50             0.333259            0.270426          1.000000
# 51             0.334114            0.271001          1.000000
# 52             0.339681            0.276581          1.000000
# 53             0.343648            0.282197          1.000000
#
#     std_test_recall  mean_test_roc_auc  std_test_roc_auc  mean_fit_time  \
# 0          0.064690           0.704989          0.173729       9.657572
# 1          0.003126           0.714887          0.181493      10.289452
# 2          0.116162           0.549602          0.058081       8.826412
# 3          0.389579           0.748210          0.194789      10.460227
# 4          0.000000           0.500000          0.000000       7.843386
# 5          0.436194           0.662386          0.218097       9.135723
# 6          0.000000           0.558022          0.071256      46.770034
# 7          0.000000           0.555725          0.070986      47.973920
# 8          0.000000           0.576263          0.082402      47.086110
# 9          0.000000           0.576518          0.079561      52.694319
# 10         0.000076           0.592558          0.082658      50.058823
# 11         0.000000           0.601888          0.081701      50.076557
# 12         0.000000           0.558646          0.070726      51.457129
# 13         0.000000           0.558692          0.068736      54.690869
# 14         0.000000           0.577800          0.080543      46.043937
# 15         0.000000           0.579025          0.077851      52.665455
# 16         0.000057           0.597817          0.081892      73.455741
# 17         0.000000           0.606754          0.082029      59.170619
# 18         0.057670           0.708848          0.181123      14.164102
# 19         0.061038           0.696955          0.159942      16.159250
# 20         0.301182           0.606484          0.150591      13.889426
# 21         0.389982           0.750650          0.194991      16.049362
# 22         0.011670           0.504126          0.005835      13.770669
# 23         0.189785           0.579070          0.094893      16.060733
# 24         0.000000           0.558094          0.071611      84.502617
# 25         0.000000           0.557584          0.072247      90.017360
# 26         0.000000           0.576324          0.082310      84.276755
# 27         0.000000           0.576455          0.081380      88.742291
# 28         0.000000           0.593894          0.082419      84.583372
# 29         0.000000           0.596736          0.081936      88.530636
# 30         0.000000           0.559226          0.071171      84.216055
# 31         0.000000           0.560157          0.072225      90.754952
# 32         0.000000           0.577777          0.081163      84.702205
# 33         0.000000           0.578258          0.080364      91.333350
# 34         0.000034           0.595822          0.082118      84.417240
# 35         0.000000           0.600879          0.081748      90.118879
# 36         0.057242           0.708527          0.181697      35.426706
# 37         0.052458           0.706296          0.177329      41.347391
# 38         0.400516           0.641604          0.200258      35.348106
# 39         0.408349           0.786750          0.204175      42.161561
# 40         0.366619           0.629619          0.183309      35.144424
# 41         0.130737           0.564894          0.065368      41.161032
# 42         0.000000           0.558605          0.071841     216.253834
# 43         0.000000           0.560145          0.073694     227.883736
# 44         0.000000           0.577249          0.081973     215.416219
# 45         0.000000           0.578472          0.082604     229.717545
# 46         0.000000           0.595267          0.082230     266.478343
# 47         0.000000           0.599419          0.081875     229.396046
# 48         0.000000           0.557952          0.071740     315.475278
# 49         0.000000           0.560347          0.073516     279.080904
# 50         0.000000           0.576061          0.081645     214.737876
# 51         0.000000           0.578177          0.082234     231.934271
# 52         0.000000           0.591099          0.082914     217.266393
# 53         0.000000           0.599561          0.081872     269.812300
#
#     std_fit_time  mean_score_time  std_score_time
# 0       4.376885         4.275401        0.234156
# 1       5.217440         4.983473        0.246042
# 2       4.355622         4.493544        0.428209
# 3       5.507685         4.711985        0.270680
# 4       3.574903         4.064210        0.160139
# 5       4.458204         4.467646        0.171688
# 6      25.471758         7.709900        1.029663
# 7      24.160423         8.197011        1.107502
# 8      24.995009         8.171039        1.123908
# 9      27.184023         8.674500        0.789215
# 10     25.826025         7.283961        0.743384
# 11     28.449931         8.023008        0.465654
# 12     26.338682         8.328678        2.179897
# 13     29.608789         8.192758        0.758747
# 14     23.668522         8.172426        0.217858
# 15     30.901898         8.612747        1.261623
# 16     43.130247        12.458512        5.225493
# 17     27.887742         9.903896        2.206317
# 18      7.073825         6.976997        0.257526
# 19      7.875375         7.812485        0.398467
# 20      6.829743         7.119377        0.184085
# 21      7.894073         7.741771        0.334694
# 22      6.617090         7.226079        0.499359
# 23      7.675602         7.784513        0.379890
# 24     45.156447        12.948744        1.021991
# 25     45.838864        14.272033        1.235737
# 26     45.374415        12.896654        0.829400
# 27     47.177306        14.392185        1.729028
# 28     45.037590        13.058375        1.283098
# 29     47.098261        14.494179        1.276391
# 30     44.438851        13.579936        0.975486
# 31     47.208376        15.167823        1.386203
# 32     43.792445        13.522702        1.015245
# 33     47.146165        15.000401        1.571758
# 34     44.140831        13.414950        1.094704
# 35     47.291611        15.212198        1.764030
# 36     18.244273        17.359402        0.711081
# 37     20.988413        19.567122        0.653231
# 38     18.179798        17.391604        0.767543
# 39     21.988881        19.705634        0.575641
# 40     18.031670        17.303242        0.662046
# 41     21.445241        19.561750        0.778630
# 42    115.565989        33.613123        3.054019
# 43    120.826390        38.431891        3.619153
# 44    115.518706        33.431346        2.797596
# 45    121.874585        38.085546        3.685644
# 46    120.503338        41.974623        9.387464
# 47    121.698122        37.438294        3.498650
# 48    204.423695        45.581654        9.229924
# 49    116.311086        48.420007        8.865458
# 50    112.673765        34.630300        2.826209
# 51    121.003565        38.976432        3.667865
# 52    113.031532        38.575850        5.666682
# 53    152.370404        43.581182        4.595432

# %%
# Identificar a melhor combinação de hiperparâmetros
best_params_idx = results_df_iforest['mean_test_roc_auc'].idxmax()
best_params_idx
best_params = results_df_iforest.loc[best_params_idx]

print("\nMelhores parâmetros encontrados:", best_params['params'])

print("\nMétricas:", best_params)
# Out:
# Melhores parâmetros encontrados: {'n_estimators': 256, 'max_samples': 'auto', 'contamination': 0.01, 'max_features': 0.7, 'n_jobs': -1}
#
# Métricas: params                   {'n_estimators': 256, 'max_samples': 'auto', '...
# fold_scores              {'test_f1_scores': [0.8898413143878615, 0.0, 0...
# mean_test_f1_score                                                 0.61587
# std_test_f1_score                                                 0.436368
# mean_test_specificity                                             0.666667
# std_test_specificity                                              0.471405
# mean_test_precision                                               0.666667
# std_test_precision                                                0.471405
# mean_test_recall                                                  0.573501
# std_test_recall                                                   0.408349
# mean_test_roc_auc                                                  0.78675
# std_test_roc_auc                                                  0.204175
# mean_fit_time                                                    42.161561
# std_fit_time                                                     21.988881
# mean_score_time                                                  19.705634
# std_score_time                                                    0.575641
# Name: 39, dtype: object

# %%
estimator_iforest = IForest(random_state=42, n_estimators= 256, max_samples= 'auto', contamination= 0.01, max_features= 0.7, n_jobs= -1)

# %%
best_model_iforest2 = Pipeline([
            ('scaler', StandardScaler()),
            ('to_dataframe', ToDataFrameTransformer(columns=VARS)),
            ('estimator', estimator_iforest)
        ])

best_model_iforest2.fit(train_no_anomalies[VARS])
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('to_dataframe',
#                  ToDataFrameTransformer(columns=['P-PDG', 'P-TPT', 'T-TPT',
#                                                  'P-MON-CKP', 'T-JUS-CKP',
#                                                  'P-JUS-CKGL', 'QGL'])),
#                 ('estimator',
#                  IForest(behaviour='old', bootstrap=False, contamination=0.01,
#     max_features=0.7, max_samples='auto', n_estimators=256, n_jobs=-1,
#     random_state=42, verbose=0))])

# %%
y_pred = best_model_iforest2.predict(test[VARS])


y_test = test.target.values

# %%
metrics(y_test, y_pred)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0    0.87907   0.99033   0.93138   1493608
#            1    0.97320   0.72055   0.82803    728192
#
#     accuracy                        0.90191   2221800
#    macro avg    0.92613   0.85544   0.87971   2221800
# weighted avg    0.90992   0.90191   0.89751   2221800
#
# Specificity: 0.9903254401422595
# Gini:  0.7108799092932527
# ROC AUC::  0.8554399546466264

# %%
with open('./models/pipeline_iForest2.pkl', 'wb') as file: 
    pickle.dump(best_model_iforest2, file)

# %%
estimator = estimator_class(random_state=42, **best_params['params'])

best_model_iforest = Pipeline([
            ('scaler', StandardScaler()),
            ('to_dataframe', ToDataFrameTransformer(columns=VARS)),
            ('estimator', estimator)
        ])

best_model_iforest.fit(train_no_anomalies[VARS])
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('to_dataframe',
#                  ToDataFrameTransformer(columns=['P-PDG', 'P-TPT', 'T-TPT',
#                                                  'P-MON-CKP', 'T-JUS-CKP',
#                                                  'P-JUS-CKGL', 'QGL'])),
#                 ('estimator',
#                  IsolationForest(contamination=0.01, max_features=0.7,
#                                  n_estimators=256, n_jobs=-1,
#                                  random_state=42))])

# %%
best_model_iforest
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('to_dataframe',
#                  ToDataFrameTransformer(columns=['P-PDG', 'P-TPT', 'T-TPT',
#                                                  'P-MON-CKP', 'T-JUS-CKP',
#                                                  'P-JUS-CKGL', 'QGL'])),
#                 ('estimator',
#                  IsolationForest(contamination=0.01, max_features=0.7,
#                                  n_estimators=256, n_jobs=-1,
#                                  random_state=42))])

# %%
scale_iforest = best_model_iforest[0]
scale_iforest
# Out:
# StandardScaler()

# %%
media = scale_iforest.mean_

desvio_padrao = scale_iforest.scale_

print("Média calculada pelo StandardScaler:", media)
print("Desvio padrão calculado pelo StandardScaler:", desvio_padrao)
# Out:
# Média calculada pelo StandardScaler: [1.01713733e+07 1.32058831e+07 1.17294754e+02 4.47385646e+06
#  7.32985921e+01 2.17328886e+06 1.96035520e-06]
# Desvio padrão calculado pelo StandardScaler: [1.88216312e+07 5.09831214e+06 8.36684233e-01 3.90022108e+06
#  1.16327041e+01 1.56808619e+06 2.93207414e-04]

# %%
y_pred = best_model_iforest.predict(test[VARS])
y_pred = np.where(y_pred == -1, 1, 0)  


y_test = test.target.values

# %%
test['iForest']  = y_test
test['scores_forest']=-best_model_iforest.decision_function(test[VARS])

# %%
train['scores_forest'] = best_model_iforest.score_samples(train[VARS])

# %%
metrics(y_test, y_pred)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0    0.87907   0.99033   0.93138   1493608
#            1    0.97320   0.72055   0.82803    728192
#
#     accuracy                        0.90191   2221800
#    macro avg    0.92613   0.85544   0.87971   2221800
# weighted avg    0.90992   0.90191   0.89751   2221800
#
# Specificity: 0.9903254401422595
# Gini:  0.7108799092932527
# ROC AUC::  0.8554399546466264

# %%
test['iForest'].value_counts()
# Out:
# iForest
# 0    1493608
# 1     728192
# Name: count, dtype: int64

# %%
g = sns.kdeplot(test["scores_forest"][(test["target"] == 0) & (test["scores_forest"].notnull())], color="Blue", fill = True)
g = sns.kdeplot(test["scores_forest"][(test["target"] == 1) & (test["scores_forest"].notnull())], color="Red", fill = True)

g.set_xlabel("scores_forest")
g.set_ylabel("Frequência")
g = g.legend(['normal', 'fraude'])

# %%
percentiles = [0, 0.01, 1, 10, 25, 50, 75, 90, 100]

# Calcular os valores dos percentis
percentile_values = np.percentile(train['scores_forest'], percentiles)

# Mostrar os percentis e seus valores correspondentes
for p, value in zip(percentiles, percentile_values):
    print(f"{p}º percentil: {value:.2f}")

# Plotar os percentis
plt.figure(figsize=(10, 6))
plt.plot(percentiles, percentile_values, marker='o', linestyle='-')
plt.xlabel('Percentil')
plt.ylabel('Score de Anomalia')
plt.title('Distribuição dos Scores de Anomalia por Percentil')
plt.grid(True)
plt.show()
# Out:
# 0º percentil: -0.73
# 0.01º percentil: -0.72
# 1º percentil: -0.72
# 10º percentil: -0.70
# 25º percentil: -0.68
# 50º percentil: -0.52
# 75º percentil: -0.43
# 90º percentil: -0.41
# 100º percentil: -0.38

# %%
sns.kdeplot(
    data=test.sample(frac=0.01), x="scores_forest", hue=test.target,
    cumulative=True, common_norm=False, common_grid=True,
)
# Out:
# <Axes: xlabel='scores_forest', ylabel='Density'>

# %%
with open('./models/pipeline_iForest.pkl', 'wb') as file: 
    pickle.dump(best_model_iforest, file)

# %% [markdown]
# ## Algorithms Pyod

# %% [markdown]
# https://pyod.readthedocs.io/en/latest/

# %% [markdown]
# #### PCA

# %%
# Definir a grade de hiperparâmetros para o PCA
param_grid = { 
    'contamination': [0.05, 0.01, 0.001],
    'n_components':[7, 5, 3],
    'n_selected_components':[None]

}
                
estimator_class = PCA

# Configurar TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=3)

# fold_ratios = [0.5, 0.6, 0.7, 0.8]

# %%
estimator_class
# Out:
# pyod.models.pca.PCA

# %%
development.shape
# Out:
# (8887177, 10)

# %%
results_df_pca = cross_validation(estimator_class, param_grid, development, tscv, VARS, scikit = False, random_state=42)
# Out:
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415

# %%
results_df_pca
# Out:
#                                               params  \
# 0  {'contamination': 0.05, 'n_components': 7, 'n_...
# 1  {'contamination': 0.05, 'n_components': 5, 'n_...
# 2  {'contamination': 0.05, 'n_components': 3, 'n_...
# 3  {'contamination': 0.01, 'n_components': 7, 'n_...
# 4  {'contamination': 0.01, 'n_components': 5, 'n_...
# 5  {'contamination': 0.01, 'n_components': 3, 'n_...
# 6  {'contamination': 0.001, 'n_components': 7, 'n...
# 7  {'contamination': 0.001, 'n_components': 5, 'n...
# 8  {'contamination': 0.001, 'n_components': 3, 'n...
#
#                                          fold_scores  mean_test_f1_score  \
# 0  {'test_f1_scores': [0.0, 0.0, 0.85560064030642...            0.285200
# 1  {'test_f1_scores': [0.4826060376699368, 0.2224...            0.520505
# 2  {'test_f1_scores': [0.8515825822181525, 0.2224...            0.644398
# 3  {'test_f1_scores': [0.0, 0.0, 1.0], 'test_spec...            0.333333
# 4  {'test_f1_scores': [0.0, 0.3384916528747559, 1...            0.446164
# 5  {'test_f1_scores': [0.0, 0.33811010475827424, ...            0.446037
# 6  {'test_f1_scores': [0.0, 0.0, 1.0], 'test_spec...            0.333333
# 7  {'test_f1_scores': [0.0, 0.33850800549190946, ...            0.446169
# 8  {'test_f1_scores': [0.0, 0.33819888157710565, ...            0.446066
#
#    std_test_f1_score  mean_test_specificity  std_test_specificity  \
# 0           0.403334               0.073125              0.103414
# 1           0.260241               0.542005              0.331427
# 2           0.298400               0.547762              0.326197
# 3           0.471405               0.333333              0.471405
# 4           0.415287               0.555153              0.415632
# 5           0.415320               0.554963              0.415582
# 6           0.471405               0.333333              0.471405
# 7           0.415286               0.555161              0.415635
# 8           0.415312               0.555007              0.415594
#
#    mean_test_precision  std_test_precision  mean_test_recall  std_test_recall  \
# 0             0.249214            0.352442          0.333333         0.471405
# 1             0.622035            0.365103          0.772956         0.321088
# 2             0.625589            0.367785          0.914118         0.121455
# 3             0.333333            0.471405          0.333333         0.471405
# 4             0.401242            0.431478          0.666667         0.471405
# 5             0.401150            0.431520          0.666667         0.471405
# 6             0.333333            0.471405          0.333333         0.471405
# 7             0.401246            0.431476          0.666667         0.471405
# 8             0.401171            0.431510          0.666667         0.471405
#
#    mean_test_roc_auc  std_test_roc_auc  mean_fit_time  std_fit_time  \
# 0           0.536563          0.051707       3.091669      1.550567
# 1           0.657481          0.036060       6.992033      2.844574
# 2           0.730940          0.104302       5.491262      2.373944
# 3           0.666667          0.235702       3.013296      1.154494
# 4           0.777576          0.207816       5.902370      3.190512
# 5           0.777481          0.207791       6.150827      2.707178
# 6           0.666667          0.235702       2.209509      1.048516
# 7           0.777581          0.207817       5.776988      3.027525
# 8           0.777503          0.207797       5.626897      2.965547
#
#    mean_score_time  std_score_time
# 0         0.615462        0.073614
# 1         0.737819        0.160342
# 2         0.459764        0.031802
# 3         0.683155        0.064390
# 4         0.572463        0.068689
# 5         0.564781        0.087274
# 6         0.605342        0.054548
# 7         0.477072        0.012743
# 8         0.547615        0.162425

# %%
results_df_pca['fold_scores'][0]
# Out:
# {'test_f1_scores': [0.0, 0.0, 0.8556006403064292],
#  'test_specificities': [0, 0, 0.21937524135555717],
#  'test_precisions': [0.0, 0.0, 0.7476416629029996],
#  'test_recalls': [0.0, 0.0, 1.0],
#  'test_roc_auc': [0.5, 0.5, 0.6096876206777786],
#  'fit_times': [1.6237080097198486, 2.414902687072754, 5.236395835876465],
#  'score_times': [0.5625863075256348, 0.5642349720001221, 0.7195634841918945]}

# %%
results_df_pca['fold_scores'][1]
# Out:
# {'test_f1_scores': [0.4826060376699368,
#   0.22241916745494136,
#   0.8564888387754404],
#  'test_specificities': [0.9994951191260502,
#   0.4015391230418935,
#   0.22498139978022666],
#  'test_precisions': [0.9919818094782192,
#   0.12512464321326633,
#   0.7489991071519112],
#  'test_recalls': [0.318869013271783, 1.0, 1.0],
#  'test_roc_auc': [0.6591820661989166, 0.7007695615209467, 0.6124906998901134],
#  'fit_times': [3.8511292934417725, 6.3856892585754395, 10.739280939102173],
#  'score_times': [0.9196486473083496, 0.7642395496368408, 0.5295686721801758]}

# %%
results_df_pca['fold_scores'][2]
# Out:
# {'test_f1_scores': [0.8515825822181525,
#   0.22241916745494136,
#   0.8591911842092144],
#  'test_specificities': [0.9997814694724695,
#   0.4015391230418935,
#   0.24196686700731038],
#  'test_precisions': [0.9984994696401315,
#   0.12512464321326633,
#   0.7531421324208828],
#  'test_recalls': [0.7423542989036354, 1.0, 1.0],
#  'test_roc_auc': [0.8710678841880525, 0.7007695615209467, 0.6209834335036553],
#  'fit_times': [2.5090062618255615, 5.6470887660980225, 8.317690372467041],
#  'score_times': [0.4348256587982178, 0.4398198127746582, 0.504645824432373]}

# %%
# Identificar a melhor combinação de hiperparâmetros
best_params_idx = results_df_pca['mean_test_roc_auc'].idxmax()
best_params_idx
best_params = results_df_pca.loc[best_params_idx]

print("\nMelhores parâmetros encontrados:", best_params['params'])

print("\nMétricas:", best_params)
# Out:
# Melhores parâmetros encontrados: {'contamination': 0.001, 'n_components': 5, 'n_selected_components': None}
#
# Métricas: params                   {'contamination': 0.001, 'n_components': 5, 'n...
# fold_scores              {'test_f1_scores': [0.0, 0.33850800549190946, ...
# mean_test_f1_score                                                0.446169
# std_test_f1_score                                                 0.415286
# mean_test_specificity                                             0.555161
# std_test_specificity                                              0.415635
# mean_test_precision                                               0.401246
# std_test_precision                                                0.431476
# mean_test_recall                                                  0.666667
# std_test_recall                                                   0.471405
# mean_test_roc_auc                                                 0.777581
# std_test_roc_auc                                                  0.207817
# mean_fit_time                                                     5.776988
# std_fit_time                                                      3.027525
# mean_score_time                                                   0.477072
# std_score_time                                                    0.012743
# Name: 7, dtype: object

# %%
estimator = estimator_class(random_state=42, **best_params['params'])

best_model_pca = Pipeline([
            ('scaler', StandardScaler()),
            ('to_dataframe', ToDataFrameTransformer(columns=VARS)), 
            ('estimator', estimator)
        ])

best_model_pca.fit(train_no_anomalies[VARS])
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('to_dataframe',
#                  ToDataFrameTransformer(columns=['P-PDG', 'P-TPT', 'T-TPT',
#                                                  'P-MON-CKP', 'T-JUS-CKP',
#                                                  'P-JUS-CKGL', 'QGL'])),
#                 ('estimator',
#                  PCA(contamination=0.001, copy=True, iterated_power='auto', n_components=5,
#   n_selected_components=None, random_state=42, standardization=True,
#   svd_solver='auto', tol=0.0, weighted=True, whiten=False))])

# %%
scale_pca = best_model_pca[0]

# %%
media = scale_pca.mean_

desvio_padrao = scale_pca.scale_

print("Média calculada pelo StandardScaler:", media)
print("Desvio padrão calculado pelo StandardScaler:", desvio_padrao)
# Out:
# Média calculada pelo StandardScaler: [1.01713733e+07 1.32058831e+07 1.17294754e+02 4.47385646e+06
#  7.32985921e+01 2.17328886e+06 1.96035520e-06]
# Desvio padrão calculado pelo StandardScaler: [1.88216312e+07 5.09831214e+06 8.36684233e-01 3.90022108e+06
#  1.16327041e+01 1.56808619e+06 2.93207414e-04]

# %%
y_pred = best_model_pca.predict(test[VARS])
y_test = test.target.values

# %%
test['pca']  = y_test
test['scores_pca']= best_model_pca.decision_function(test[VARS])

# %%
train['scores_pca'] = best_model_pca.decision_function(train[VARS])

# %%
metrics(y_test, y_pred)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0    1.00000   0.99021   0.99508   1493608
#            1    0.98032   1.00000   0.99006    728192
#
#     accuracy                        0.99342   2221800
#    macro avg    0.99016   0.99511   0.99257   2221800
# weighted avg    0.99355   0.99342   0.99344   2221800
#
# Specificity: 0.9902102827515653
# Gini:  0.9902102827515653
# ROC AUC::  0.9951051413757827

# %%
sns.kdeplot(
    data=test.sample(frac=0.01), x="scores_pca", hue=test.target,
    cumulative=True, common_norm=False, common_grid=True,
)
# Out:
# <Axes: xlabel='scores_pca', ylabel='Density'>

# %%
g = sns.kdeplot(test["scores_pca"][(test["target"] == 0) & (test["scores_pca"].notnull())], color="Blue", fill = True)
g = sns.kdeplot(test["scores_pca"][(test["target"] == 1) & (test["scores_pca"].notnull())], ax =g, color="Red", fill= True)

g.set_xlabel("scores_pca")
g.set_ylabel("Frequência")
g = g.legend(['normal', 'anomalia'])

# %%
with open('./models/pipeline_PCA.pkl', 'wb') as file: 
    pickle.dump(best_model_pca, file)

# %% [markdown]
# #### LODA

# %%
# Definir a grade de hiperparâmetros para o PCA
param_grid = { 
    'contamination': [0.05, 0.01, 0.001],
    'n_bins':[500, 1000, 2000],
    'n_random_cuts':[100, 500, 1000]

}
                
estimator_class = LODA

# Configurar TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=3)

# %%
results_df_loda = cross_validation(estimator_class, param_grid, development, tscv, VARS, scikit = False, random_state=None)
# Out:
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415

# %%
results_df_loda
# Out:
#                                                params  \
# 0   {'contamination': 0.05, 'n_bins': 500, 'n_rand...
# 1   {'contamination': 0.05, 'n_bins': 500, 'n_rand...
# 2   {'contamination': 0.05, 'n_bins': 500, 'n_rand...
# 3   {'contamination': 0.05, 'n_bins': 1000, 'n_ran...
# 4   {'contamination': 0.05, 'n_bins': 1000, 'n_ran...
# 5   {'contamination': 0.05, 'n_bins': 1000, 'n_ran...
# 6   {'contamination': 0.05, 'n_bins': 2000, 'n_ran...
# 7   {'contamination': 0.05, 'n_bins': 2000, 'n_ran...
# 8   {'contamination': 0.05, 'n_bins': 2000, 'n_ran...
# 9   {'contamination': 0.01, 'n_bins': 500, 'n_rand...
# 10  {'contamination': 0.01, 'n_bins': 500, 'n_rand...
# 11  {'contamination': 0.01, 'n_bins': 500, 'n_rand...
# 12  {'contamination': 0.01, 'n_bins': 1000, 'n_ran...
# 13  {'contamination': 0.01, 'n_bins': 1000, 'n_ran...
# 14  {'contamination': 0.01, 'n_bins': 1000, 'n_ran...
# 15  {'contamination': 0.01, 'n_bins': 2000, 'n_ran...
# 16  {'contamination': 0.01, 'n_bins': 2000, 'n_ran...
# 17  {'contamination': 0.01, 'n_bins': 2000, 'n_ran...
# 18  {'contamination': 0.001, 'n_bins': 500, 'n_ran...
# 19  {'contamination': 0.001, 'n_bins': 500, 'n_ran...
# 20  {'contamination': 0.001, 'n_bins': 500, 'n_ran...
# 21  {'contamination': 0.001, 'n_bins': 1000, 'n_ra...
# 22  {'contamination': 0.001, 'n_bins': 1000, 'n_ra...
# 23  {'contamination': 0.001, 'n_bins': 1000, 'n_ra...
# 24  {'contamination': 0.001, 'n_bins': 2000, 'n_ra...
# 25  {'contamination': 0.001, 'n_bins': 2000, 'n_ra...
# 26  {'contamination': 0.001, 'n_bins': 2000, 'n_ra...
#
#                                           fold_scores  mean_test_f1_score  \
# 0   {'test_f1_scores': [0.2814917601414536, 0.2224...            0.446762
# 1   {'test_f1_scores': [0.2814917601414536, 0.2223...            0.446359
# 2   {'test_f1_scores': [0.2814917601414536, 0.2223...            0.452225
# 3   {'test_f1_scores': [0.2814917601414536, 0.2220...            0.446124
# 4   {'test_f1_scores': [0.2814917601414536, 0.2219...            0.443694
# 5   {'test_f1_scores': [0.2814917601414536, 0.2222...            0.447103
# 6   {'test_f1_scores': [0.2814917601414536, 0.2221...            0.446575
# 7   {'test_f1_scores': [0.2814917601414536, 0.2222...            0.442051
# 8   {'test_f1_scores': [0.2814917601414536, 0.2221...            0.450486
# 9   {'test_f1_scores': [0.2763281920947347, 0.3162...            0.495315
# 10  {'test_f1_scores': [0.2780254669700165, 0.5737...            0.579026
# 11  {'test_f1_scores': [0.2718065612879113, 0.5358...            0.561210
# 12  {'test_f1_scores': [0.27841241269707206, 1.0, ...            0.713070
# 13  {'test_f1_scores': [0.28053152135217546, 0.321...            0.494853
# 14  {'test_f1_scores': [0.27852646178044144, 0.291...            0.478669
# 15  {'test_f1_scores': [0.2814917601414536, 0.2862...            0.469746
# 16  {'test_f1_scores': [0.281239834528854, 0.22814...            0.458270
# 17  {'test_f1_scores': [0.28142795483340993, 0.289...            0.477573
# 18  {'test_f1_scores': [0.24323073097312456, 0.292...            0.477931
# 19  {'test_f1_scores': [0.2696025402284617, 0.4540...            0.536749
# 20  {'test_f1_scores': [0.2560199186956771, 0.3785...            0.508603
# 21  {'test_f1_scores': [0.28014086812945654, 0.343...            0.498370
# 22  {'test_f1_scores': [0.27632886070833007, 0.379...            0.511294
# 23  {'test_f1_scores': [0.27067665076377095, 0.379...            0.508852
# 24  {'test_f1_scores': [0.28059539323999294, 0.382...            0.512731
# 25  {'test_f1_scores': [0.2814007032058871, 0.2982...            0.484219
# 26  {'test_f1_scores': [0.2813541740394668, 0.2925...            0.485286
#
#     std_test_f1_score  mean_test_specificity  std_test_specificity  \
# 0            0.276558               0.165559              0.171306
# 1            0.276010               0.162917              0.172371
# 2            0.284300               0.201042              0.163830
# 3            0.275908               0.161685              0.172262
# 4            0.272549               0.145509              0.180598
# 5            0.277143               0.167955              0.170065
# 6            0.276451               0.164545              0.171289
# 7            0.270028               0.134037              0.188782
# 8            0.282012               0.190134              0.164147
# 9            0.281903               0.491230              0.408437
# 10           0.247937               0.424478              0.356734
# 11           0.247280               0.448485              0.414698
# 12           0.312559               0.417338              0.424656
# 13           0.274855               0.376542              0.303572
# 14           0.273679               0.288887              0.238724
# 15           0.262841               0.233906              0.245624
# 16           0.288720               0.233873              0.174981
# 17           0.271432               0.278821              0.237613
# 18           0.297987               0.385091              0.272372
# 19           0.258562               0.484348              0.408848
# 20           0.275140               0.478484              0.409381
# 21           0.265408               0.440255              0.416900
# 22           0.262543               0.451927              0.413870
# 23           0.263452               0.448546              0.414683
# 24           0.259831               0.491394              0.407786
# 25           0.275015               0.308158              0.244174
# 26           0.280543               0.322352              0.242804
#
#     mean_test_precision  std_test_precision  mean_test_recall  \
# 0              0.335900            0.271197          1.000000
# 1              0.335312            0.270381          1.000000
# 2              0.344102            0.282806          1.000000
# 3              0.335053            0.270157          1.000000
# 4              0.331519            0.265208          1.000000
# 5              0.336443            0.272030          1.000000
# 6              0.335683            0.270990          1.000000
# 7              0.329064            0.261613          1.000000
# 8              0.341535            0.279283          1.000000
# 9              0.658035            0.359719          0.719159
# 10             0.452769            0.260603          0.995233
# 11             0.645894            0.356345          0.775331
# 12             0.639223            0.351850          0.995764
# 13             0.385597            0.286610          0.920291
# 14             0.365358            0.281267          0.995920
# 15             0.352386            0.264397          1.000000
# 16             0.351733            0.291005          0.999653
# 17             0.363276            0.278097          0.999912
# 18             0.383962            0.321809          0.937477
# 19             0.654457            0.360492          0.743150
# 20             0.651043            0.363688          0.709901
# 21             0.645337            0.353409          0.733810
# 22             0.647669            0.355521          0.737712
# 23             0.645709            0.356648          0.729998
# 24             0.634460            0.336976          0.730556
# 25             0.371221            0.285318          0.999875
# 26             0.374640            0.292927          0.999810
#
#     std_test_recall  mean_test_roc_auc  std_test_roc_auc  mean_fit_time  \
# 0          0.000000           0.582779          0.085653      20.187006
# 1          0.000000           0.581459          0.086186      91.803122
# 2          0.000000           0.600521          0.081915     182.100768
# 3          0.000000           0.580843          0.086131      18.815317
# 4          0.000000           0.572755          0.090299      97.772286
# 5          0.000000           0.583977          0.085033     192.050260
# 6          0.000000           0.582273          0.085644      20.574219
# 7          0.000000           0.567018          0.094391      97.453832
# 8          0.000000           0.595067          0.082073     197.575292
# 9          0.375719           0.605194          0.099498      19.104915
# 10         0.006742           0.709855          0.181213      91.525200
# 11         0.289875           0.611908          0.093305     183.051325
# 12         0.005991           0.706551          0.214420      18.971034
# 13         0.109932           0.648416          0.109227     101.281582
# 14         0.005769           0.642404          0.121840     192.384533
# 15         0.000000           0.616953          0.122812      20.765301
# 16         0.000491           0.616763          0.087722     101.167516
# 17         0.000124           0.639367          0.118858     199.949671
# 18         0.066571           0.661284          0.169039      18.599234
# 19         0.318075           0.613749          0.102009      94.272681
# 20         0.339537           0.594193          0.111217     184.643466
# 21         0.372510           0.587033          0.067626      22.962952
# 22         0.355989           0.594820          0.078579      94.562259
# 23         0.350889           0.589272          0.082038     192.178262
# 24         0.347053           0.610975          0.088879      19.674177
# 25         0.000177           0.654016          0.122166     102.589726
# 26         0.000268           0.661081          0.121528     200.905081
#
#     std_fit_time  mean_score_time  std_score_time
# 0       9.988630         9.216328        0.931411
# 1      44.220475        45.887806        1.908271
# 2      93.109245        87.317151        3.589885
# 3       8.103868         9.540092        0.891441
# 4      46.265967        44.599379        0.796924
# 5      93.997668        91.651616        1.412759
# 6       9.915465        10.074960        1.201929
# 7      48.768504        51.702844        3.287232
# 8      98.995165        96.661034        3.643783
# 9       8.980261         9.225854        0.974324
# 10     45.751922        46.741214        2.205561
# 11     93.483142        88.602883        3.665667
# 12      8.109734         9.263421        0.881450
# 13     46.681179        43.716285        0.842231
# 14     92.746824        92.598383        3.977703
# 15      9.373480         9.998028        1.408462
# 16     50.358012        47.889444        1.665054
# 17     97.488856        96.490641        3.618217
# 18      7.782957         9.088144        1.109249
# 19     42.616370        43.357973        1.263141
# 20     92.472195        88.912557        1.316543
# 21     11.922135         9.862305        0.875737
# 22     47.206524        46.250116        3.533427
# 23     94.397502        94.084090        3.001079
# 24      8.526472         9.652043        0.399649
# 25     48.840578        46.594806        2.280968
# 26     97.857881        97.965073        1.688678

# %%
# Identificar a melhor combinação de hiperparâmetros
best_params_idx = results_df_loda['mean_test_roc_auc'].idxmax()
best_params_idx
best_params = results_df_loda.loc[best_params_idx]

print("\nMelhores parâmetros encontrados:", best_params['params'])

print("\nMétricas:", best_params)
# Out:
# Melhores parâmetros encontrados: {'contamination': 0.001, 'n_bins': 2000, 'n_random_cuts': 500}
#
# Métricas: params                   {'contamination': 0.001, 'n_bins': 2000, 'n_ra...
# fold_scores              {'test_f1_scores': [0.27885651869941686, 0.560...
# mean_test_f1_score                                                0.575395
# std_test_f1_score                                                 0.248336
# mean_test_specificity                                               0.4248
# std_test_specificity                                              0.353683
# mean_test_precision                                               0.449404
# std_test_precision                                                0.262275
# mean_test_recall                                                  0.996374
# std_test_recall                                                   0.005128
# mean_test_roc_auc                                                 0.710587
# std_test_roc_auc                                                  0.179024
# mean_fit_time                                                   105.565235
# std_fit_time                                                     49.248113
# mean_score_time                                                  50.344287
# std_score_time                                                    1.106288
# Name: 17, dtype: object

# %%
best_params = {'contamination': 0.001, 'n_bins': 2000, 'n_random_cuts': 500}

# %%
estimator = estimator_class(**best_params['params'])

best_model_loda = Pipeline([
            ('scaler', StandardScaler()),
            ('to_dataframe', ToDataFrameTransformer(columns=VARS)), 
            ('estimator', estimator)
        ])

best_model_loda.fit(train_no_anomalies[VARS])
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('to_dataframe',
#                  ToDataFrameTransformer(columns=['P-PDG', 'P-TPT', 'T-TPT',
#                                                  'P-MON-CKP', 'T-JUS-CKP',
#                                                  'P-JUS-CKGL', 'QGL'])),
#                 ('estimator',
#                  LODA(contamination=0.001, n_bins=2000, n_random_cuts=500))])

# %%
y_pred = best_model_loda.predict(test[VARS])
y_test = test.target.values

# %%
test['loda']  = y_test
test['scores_loda']= best_model_loda.decision_function(test[VARS])

# %%
metrics(y_test, y_pred)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0    1.00000   0.98588   0.99289   1493608
#            1    0.97185   1.00000   0.98572    728192
#
#     accuracy                        0.99051   2221800
#    macro avg    0.98592   0.99294   0.98931   2221800
# weighted avg    0.99077   0.99051   0.99054   2221800
#
# Specificity: 0.9858764816471256
# Gini:  0.9858764816471255
# ROC AUC::  0.9929382408235627

# %%
g = sns.kdeplot(test["scores_loda"][(test["target"] == 0) & (test["scores_loda"].notnull())], color="Blue", fill = True)
g = sns.kdeplot(test["scores_loda"][(test["target"] == 1) & (test["scores_loda"].notnull())], ax =g, color="Red", fill= True)

g.set_xlabel("scores_loda")
g.set_ylabel("Frequência")
g = g.legend(['normal', 'anomalia'])

# %%
# filename= './models/LODA.sav'
# joblib.dump(clf_LODA, filename)

with open('./models/pipeline_LODA.pkl', 'wb') as file: 
    pickle.dump(best_model_loda, file)

# %% [markdown]
# ### SGDOneClassSVM

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDOneClassSVM.html#sklearn.linear_model.SGDOneClassSVM

# %%
param_grid = { 
    'nu': [0.001, 0.01, 0.05],
    'eta0': [0.01, 0.05, 0.1],
    'learning_rate':['constant', 'optimal', 'invscaling', 'adaptive']
}

kernels = ['rbf', 'poly', 'sigmoid', 'linear']
                
estimator_class = SGDOneClassSVM

# Configurar TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=3)

# %%
results_df_svm =  cross_validation_ocsvm(estimator_class, param_grid,  development, tscv, VARS, scikit = True, random_state=42, kernels=kernels)
# Out:
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.001, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.01, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.05, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'constant'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'optimal'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'invscaling'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: rbf e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: poly e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: sigmoid e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# Treinando com kernel: linear e parâmetros: {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'adaptive'}
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415

# %%
# results_df_svm = cross_validation(estimator_class, param_grid, development, tscv, VARS, scikit = True, random_state=42)
# Out:
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415
# taxa de anomalias: 0.16380006427238528
# taxa de anomalias: 0.07884349314112829
# taxa de anomalias: 0.6981308798205415

# %%
results_df_svm
# Out:
#       kernel                                             params  \
# 0        rbf  {'nu': 0.001, 'eta0': 0.01, 'learning_rate': '...
# 1       poly  {'nu': 0.001, 'eta0': 0.01, 'learning_rate': '...
# 2    sigmoid  {'nu': 0.001, 'eta0': 0.01, 'learning_rate': '...
# 3     linear  {'nu': 0.001, 'eta0': 0.01, 'learning_rate': '...
# 4        rbf  {'nu': 0.001, 'eta0': 0.01, 'learning_rate': '...
# ..       ...                                                ...
# 139   linear  {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'in...
# 140      rbf  {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'ad...
# 141     poly  {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'ad...
# 142  sigmoid  {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'ad...
# 143   linear  {'nu': 0.05, 'eta0': 0.1, 'learning_rate': 'ad...
#
#                                            fold_scores  mean_test_f1_score  \
# 0    {'test_f1_scores': [0.2730417182263069, 0.0, 0...            0.091014
# 1    {'test_f1_scores': [0.2730417182263069, 0.0, 0...            0.208947
# 2    {'test_f1_scores': [0.2730417182263069, 0.0, 0...            0.309033
# 3    {'test_f1_scores': [0.2730417182263069, 0.0, 0...            0.292732
# 4    {'test_f1_scores': [0.2808914040856214, 0.0, 0...            0.093630
# ..                                                 ...                 ...
# 139  {'test_f1_scores': [0.2814917601414536, 0.2223...            0.331011
# 140  {'test_f1_scores': [0.2814917601414536, 0.2223...            0.493992
# 141  {'test_f1_scores': [0.2814917601414536, 0.2223...            0.410216
# 142  {'test_f1_scores': [0.2814917601414536, 0.2223...            0.390463
# 143  {'test_f1_scores': [0.2814917601414536, 0.2223...            0.328105
#
#      std_test_f1_score  mean_test_specificity  std_test_specificity  \
# 0             0.128713               0.000000              0.000000
# 1             0.356985               0.342197              0.465516
# 2             0.385061               0.523197              0.466795
# 3             0.345779               0.531102              0.454731
# 4             0.132413               0.000000              0.000000
# ..                 ...                    ...                   ...
# 139           0.352162               0.625740              0.390265
# 140           0.343200               0.432639              0.366734
# 141           0.413877               0.544738              0.424068
# 142           0.368279               0.641458              0.377637
# 143           0.344297               0.619826              0.389277
#
#      mean_test_precision  std_test_precision  mean_test_recall  \
# 0               0.053004            0.074959          0.321745
# 1               0.193664            0.365207          0.322038
# 2               0.342199            0.448919          0.356394
# 3               0.356919            0.445372          0.371052
# 4               0.054487            0.077056          0.332506
# ..                   ...                 ...               ...
# 139             0.369543            0.418419          0.446975
# 140             0.415367            0.383480          1.000000
# 141             0.374714            0.431336          0.660568
# 142             0.380611            0.397606          0.564311
# 143             0.385742            0.406449          0.510268
#
#      std_test_recall  mean_test_roc_auc  std_test_roc_auc  mean_fit_time  \
# 0           0.455016           0.494206          0.008194      19.138902
# 1           0.450375           0.498784          0.272176      22.688513
# 2           0.409989           0.550907          0.268527      21.505678
# 3           0.414717           0.576077          0.246344      19.442581
# 4           0.470235           0.499586          0.000585      18.905784
# ..               ...                ...               ...            ...
# 139         0.431981           0.578024          0.246915      19.488802
# 140         0.000000           0.716320          0.183367      65.949254
# 141         0.463562           0.602653          0.326072      71.265059
# 142         0.434496           0.602884          0.272881      68.843176
# 143         0.451165           0.606714          0.248289      67.253799
#
#      std_fit_time  mean_score_time  std_score_time
# 0        9.564765         9.218007        1.691062
# 1       11.693232        11.048849        2.206661
# 2       11.147509         9.682063        2.733823
# 3       10.833062         8.407591        3.276024
# 4        8.064074        10.229966        3.220517
# ..            ...              ...             ...
# 139     11.826600         7.900841        4.040047
# 140     33.353786         7.999381        1.682653
# 141     37.875206        11.395234        3.790480
# 142     36.605666         9.662899        3.954577
# 143     35.545731         8.056513        4.412660
#
# [144 rows x 17 columns]

# %%
results_df_svm['fold_scores'][0]
# Out:
# {'test_f1_scores': [0.2808914040856214, 0.0, 0.0],
#  'test_specificities': [0.0, 0, 0],
#  'test_precisions': [0.16346007075538602, 0.0, 0.0],
#  'test_recalls': [0.9975187536064628, 0.0, 0.0],
#  'test_roc_auc': [0.4987593768032314, 0.5, 0.5],
#  'fit_times': [6.552067041397095, 20.696141719818115, 27.470924854278564],
#  'score_times': [6.686821222305298, 6.899582386016846, 10.433214664459229]}

# %%
results_df_svm['fold_scores'][1]
# Out:
# {'test_f1_scores': [0.28144722985299286, 0.33795257543808205, 1.0],
#  'test_specificities': [0.0, 0.6646519627483363, 1.0],
#  'test_precisions': [0.16377484722470403, 0.20333509768962188, 1.0],
#  'test_recalls': [0.9998158986618306, 1.0, 1.0],
#  'test_roc_auc': [0.4999079493309153, 0.8323259813741681, 1.0],
#  'fit_times': [6.010940074920654, 16.091143131256104, 32.98112750053406],
#  'score_times': [6.257837772369385, 6.017680883407593, 10.921159505844116]}

# %%
results_df_svm['fold_scores'][2]
# Out:
# {'test_f1_scores': [0.2814917601414536,
#   0.2223392751069976,
#   0.9771090705103371],
#  'test_specificities': [0, 0.4012625695048421, 0.8916401144491278],
#  'test_precisions': [0.16380006427238528,
#   0.12507407740606985,
#   0.9552426777289273],
#  'test_recalls': [1.0, 1.0, 1.0],
#  'test_roc_auc': [0.5, 0.7006312847524211, 0.9458200572245639],
#  'fit_times': [6.22400975227356, 16.306185483932495, 26.960662364959717],
#  'score_times': [5.903992414474487, 5.8656463623046875, 13.004470109939575]}

# %%
# Identificar a melhor combinação de hiperparâmetros
best_params_idx = results_df_svm['mean_test_roc_auc'].idxmax()
best_params_idx
best_params = results_df_svm.loc[best_params_idx]

print("\nMelhores parâmetros encontrados:", best_params['params'])

print("\nMétricas:", best_params)
# Out:
# Melhores parâmetros encontrados: {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}
#
# Métricas: kernel                                                                 rbf
# params                   {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'ad...
# fold_scores              {'test_f1_scores': [0.28148444935690853, 0.338...
# mean_test_f1_score                                                 0.53984
# std_test_f1_score                                                   0.3262
# mean_test_specificity                                             0.554925
# std_test_specificity                                              0.415572
# mean_test_precision                                                0.45573
# std_test_precision                                                0.385196
# mean_test_recall                                                   0.99999
# std_test_recall                                                   0.000014
# mean_test_roc_auc                                                 0.777458
# std_test_roc_auc                                                  0.207793
# mean_fit_time                                                    65.045214
# std_fit_time                                                     32.253519
# mean_score_time                                                   8.184244
# std_score_time                                                    1.746166
# Name: 92, dtype: object

# %%
# Identificar a melhor combinação de hiperparâmetros
best_params_idx = results_df_svm['mean_test_roc_auc'].idxmax()
best_params_idx
best_params = results_df_svm.loc[best_params_idx]

print("\nMelhores parâmetros encontrados:", best_params['params'])

print("\nMétricas:", best_params)
# Out:
# Melhores parâmetros encontrados: {'nu': 0.01}
#
# Métricas: params                                                        {'nu': 0.01}
# fold_scores              {'test_f1_scores': [0.28144722985299286, 0.337...
# mean_test_f1_score                                                  0.5398
# std_test_f1_score                                                 0.326227
# mean_test_specificity                                             0.554884
# std_test_specificity                                              0.415561
# mean_test_precision                                               0.455703
# std_test_precision                                                0.385215
# mean_test_recall                                                  0.999939
# std_test_recall                                                   0.000087
# mean_test_roc_auc                                                 0.777411
# std_test_roc_auc                                                  0.207822
# mean_fit_time                                                     18.36107
# std_fit_time                                                      11.12691
# mean_score_time                                                   7.732226
# std_score_time                                                    2.257047
# Name: 1, dtype: object

# %%
best_params = {'nu': 0.01, 'eta0': 0.1, 'learning_rate': 'adaptive'}

# %%
transform = Nystroem(gamma=None, random_state=42)
estimator = estimator_class(random_state=42, **best_params)
estimator = make_pipeline(transform, estimator)


best_model_svm = Pipeline([
            ('scaler', StandardScaler()),
            ('to_dataframe', ToDataFrameTransformer(columns=VARS)), 
            ('estimator', estimator)
        ])

best_model_svm.fit(train_no_anomalies[VARS])
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('to_dataframe',
#                  ToDataFrameTransformer(columns=['P-PDG', 'P-TPT', 'T-TPT',
#                                                  'P-MON-CKP', 'T-JUS-CKP',
#                                                  'P-JUS-CKGL', 'QGL'])),
#                 ('estimator',
#                  Pipeline(steps=[('nystroem', Nystroem(random_state=42)),
#                                  ('sgdoneclasssvm',
#                                   SGDOneClassSVM(eta0=0.1,
#                                                  learning_rate='adaptive',
#                                                  nu=0.01,
#                                                  random_state=42))]))])

# %%
transform = Nystroem(gamma=None, random_state=42)
estimator = estimator_class(random_state=42, **best_params['params'])
estimator = make_pipeline(transform, estimator)


best_model_svm = Pipeline([
            ('scaler', StandardScaler()),
            ('to_dataframe', ToDataFrameTransformer(columns=VARS)), 
            ('estimator', estimator)
        ])

best_model_svm.fit(train_no_anomalies[VARS])
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('to_dataframe',
#                  ToDataFrameTransformer(columns=['P-PDG', 'P-TPT', 'T-TPT',
#                                                  'P-MON-CKP', 'T-JUS-CKP',
#                                                  'P-JUS-CKGL', 'QGL'])),
#                 ('estimator',
#                  Pipeline(steps=[('nystroem', Nystroem(random_state=42)),
#                                  ('sgdoneclasssvm',
#                                   SGDOneClassSVM(nu=0.01, random_state=42))]))])

# %%
y_pred = best_model_svm.predict(test[VARS])
y_pred = np.where(y_pred == -1, 1, 0)  


y_test = test.target.values

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
test['scores_ocsvm']= -best_model_svm.decision_function(test[VARS])

# %%
metrics(y_test, y_pred)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0    1.00000   0.86369   0.92686   1493608
#            1    0.78150   1.00000   0.87735    728192
#
#     accuracy                        0.90836   2221800
#    macro avg    0.89075   0.93184   0.90211   2221800
# weighted avg    0.92839   0.90836   0.91063   2221800
#
# Specificity: 0.8636891339628604
# Gini:  0.8636891339628603
# ROC AUC::  0.9318445669814301

# %%
g = sns.kdeplot(test["scores_ocsvm"][(test["target"] == 0) & (test["scores_ocsvm"].notnull())], color="Blue", fill = True)
g = sns.kdeplot(test["scores_ocsvm"][(test["target"] == 1) & (test["scores_ocsvm"].notnull())], ax =g, color="Red", fill= True)

g.set_xlabel("scores_ocsvm")
g.set_ylabel("Frequência")
g = g.legend(['normal', 'anomalia'])

# %%
with open('./models/pipeline_SGDOSVM.pkl', 'wb') as file: 
    pickle.dump(best_model_svm, file)

# %%
# ### Local Outlier Factor
# lof = LocalOutlierFactor(n_neighbors=15, novelty=True, p=2, metric = 'minkowski', contamination=0.33)
# inicio = time.time()
# lof.fit(X_train_p[VARS])
# fim = time.time()
# print("time train")
# print((fim - inicio)/60)
# with open('./models/LOF_temp.pkl', 'wb') as file: 
#     pickle.dump(lof, file)
# test['score_LOF']=lof.decision_function(X_test_p[VARS])
# predictions=lof.predict(X_test_p[VARS])
# binary_predictions = np.where(predictions == -1, 1, 0)
# test['LOF'] = binary_predictions
# train['score_LOF']=lof.decision_function(X_train_p[VARS])
# predictions =lof.predict(X_train_p[VARS])
# binary_predictions = np.where(predictions == -1, 1, 0)
# train['LOF'] =  binary_predictions
# metrics(train.target, train.LOF)
# metrics(test.target, test.LOF)
# filename= './models/LOF.sav'
# joblib.dump(lof, filename)


# with open('./models/LOF.pkl', 'wb') as file: 
#     pickle.dump(lof, file)

# %%
# from sklearn.model_selection import TimeSeriesSplit

# for poço_id, poço_data in df.groupby('poço_id'):
#     poço_data = poço_data.sort_values(by='date')
#     tscv = TimeSeriesSplit(n_splits=3)
#     for train_index, test_index in tscv.split(poço_data):
#         train, test = poço_data.iloc[train_index], poço_data.iloc[test_index]
        
#         model = IsolationForest(contamination=0.1, random_state=42)
#         model.fit(train[['value']])
        
#         test['anomaly_score'] = model.decision_function(test[['value']])
#         test['anomaly'] = model.predict(test[['value']])
        
#         results.append(test[['date', 'poço_id', 'value', 'anomaly_score', 'anomaly']])

# %%
# # Ordenar os dados por poço e por data para garantir a ordem temporal
# df = data.sort_values(by=['well', 'timestamp'])

# # Configuração do GroupKFold
# gkf = GroupKFold(n_splits=2)


# for train_index, test_index in gkf.split(df, groups=df['well']):
#     train, test = df.iloc[train_index], df.iloc[test_index]
    
#     print(f'Treino Poços: {train.well.unique()}')
#     print(f'Teste Poços: {test.well.unique()}')
#     print(f'Tamanho do treino: {len(train)}')
#     print(f'Tamanho do teste: {len(test)}')



# # Separar dados por poço
# train_pocos, test_pocos = train_test_split(data['well'].unique(), test_size=0.2, random_state=42)

# train = data[data['well'].isin(train_pocos)].sort_values(by=['well', 'timestamp'])
# test = data[data['well'].isin(test_pocos)].sort_values(by=['well', 'timestamp'])

# print(f'Treino Poços: {train_pocos}')
# print(f'Teste Poços: {test_pocos}')
# print(f'Tamanho do treino: {len(train)}')
# print(f'Tamanho do teste: {len(test)}')
